# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 总结kNN算法

# %% [markdown]
# + 解决分类问题
# + 天然可以解决分类问题
# + 思想简单，效果强大
#
#
# + 解决回归问题
# + KNeighborsRegressor

# %% [markdown]
# ### 缺点

# %% [markdown]
# + 效率低下
# + 使用树结构增加效率
#
#
# + 高度数据相关  少错误导致大问题
# + 预测结果不具有可解释性
#
#
# + 维数灾难 无法进行高纬度的运算
