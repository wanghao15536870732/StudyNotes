# %% [markdown]
# ## 多元线性回归
# $$X_b = \left\lgroup\begin{matrix}1 & X_1(1) & X_2(1) & ... & X_n(1) \cr 1 & X_1(2) & X_2(2) & ... & X_n(2) \cr ... & & & & ...\cr 1 & X_1(m) & X_2(m) & ... & X_n(m)\end{matrix}\right\rgroup , \theta = \left\lgroup\begin{matrix} \theta_0 \cr \theta_1 \cr \theta_2 \cr ... \cr \theta_n \end{matrix}\right\rgroup$$
# ### $$\hat{y} = X_b \cdot \theta $$

# %% [markdown]
# 目标：
# $$使 \sum_{i=1}^{m}{(y_i - \hat{y_i})^2}尽可能小$$

# %% [markdown]
# 转换向量即为：
# $$估计一个\theta 使 (y - X_b \cdot \theta)^T(y - X_b \cdot \theta)尽可能小$$

# %% [markdown]
# ### 推导的结果为：
# ### $$\theta = (X_b^TX_b)^{-1}X_b^Ty$$

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
boston = datasets.load_boston()

X = boston.data
y = boston.target

X = X[y < 50.0]
y = y[y < 50.0]

# %%
X.shape
# Out:
# (490, 13)

# %%
from model_selection import train_test_split
X_train,y_train,X_test,y_test = train_test_split(X,y,seed=666)

# %%
from LinearRegression import LinearRegression

reg = LinearRegression()
reg.fit_normal(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-1.18919477e-01,  3.63991462e-02, -3.56494193e-02,  5.66737830e-02,
#        -1.16195486e+01,  3.42022185e+00, -2.31470282e-02, -1.19509560e+00,
#         2.59339091e-01, -1.40112724e-02, -8.36521175e-01,  7.92283639e-03,
#        -3.81966137e-01])

# %%
reg.interception_
# Out:
# 34.16143549622471

# %%
reg.score(X_test,y_test)
# Out:
# 0.8129802602658466

# %%
from mpl_toolkits.mplot3d import Axes3D #的 导入3D图形库

# %%
fig = plt.figure() # 先定义一个图像窗口
ax = Axes3D(fig) # 在窗口上添加3D坐标轴
 # 填充颜色
ax.plot_surface(X,y,rstride=1,cstride=1,cmap=plt.get_cmap('rainbow')) # rstride:row的跨度 cstride: col的跨度

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-89f21caaad27> in <module>()
#       2 ax = Axes3D(fig) # 在窗口上添加3D坐标轴
#       3  # 填充颜色
# ----> 4 ax.plot_surface(X,X,y,rstride=1,cstride=1,cmap=plt.get_cmap('rainbow')) # rstride:row的跨度 cstride: col的跨度
#       5
#       6 plt.show()
#
# d:\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1620
#    1621         if Z.ndim != 2:
# -> 1622             raise ValueError("Argument Z must be 2-dimensional.")
#    1623         # TODO: Support masked arrays
#    1624         X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.
